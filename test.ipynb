# %% [markdown]
# ## Test generator & checker for class Matrix

# %%
import numpy as np
from matrix import Matrix
import random
import sys

# %%
def assert_close(a, b, tolerance=1e-10):
    if isinstance(a, (int, float)) and isinstance(b, (int, float)):
        assert abs(a - b) < tolerance, f"{a} is not close to {b}"
    elif isinstance(a, list) and isinstance(b, list):
        assert len(a) == len(b), "Lists have different lengths"
        for i in range(len(a)):
            assert_close(a[i], b[i], tolerance)
    elif isinstance(a, Matrix) and isinstance(b, np.ndarray):
        assert a.rows == b.shape[0] and a.cols == b.shape[1], "Matrices have different shapes"
        for i in range(a.rows):
            for j in range(a.cols):
                assert_close(a.matrix[i][j], b[i, j], tolerance)
    else:
        raise ValueError("Unsupported types for comparison")

def random_matrix(rows, cols, min_val=-10, max_val=10):
    return Matrix([[random.uniform(min_val, max_val) for _ in range(cols)] for _ in range(rows)])

def print_matrix(matrix):
    for row in matrix:
        print(" ".join(f"{x:8.4f}" for x in row))

def test_matrix_operations(num_tests=50):
    print(f"\nTesting matrix operations ({num_tests} tests):")
    for i in range(num_tests):
        rows, cols = random.randint(2, 5), random.randint(2, 5)
        A = random_matrix(rows, cols)
        B = random_matrix(rows, cols)
        scalar = random.uniform(-10, 10)

        print(f"\nTest {i+1}:")
        print("Matrix A:")
        print_matrix(A.matrix)
        print("Matrix B:")
        print_matrix(B.matrix)
        print(f"Scalar: {scalar:.4f}")

        # Test addition
        print("Testing addition (A + B)...")
        C = A + B
        assert_close(C, np.array(A.matrix) + np.array(B.matrix))
        print("Addition passed.")

        # Test subtraction
        print("Testing subtraction (A - B)...")
        D = A - B
        assert_close(D, np.array(A.matrix) - np.array(B.matrix))
        print("Subtraction passed.")

        # Test multiplication (matrix-scalar)
        print(f"Testing scalar multiplication (A * {scalar:.4f})...")
        E = A * scalar
        assert_close(E, np.array(A.matrix) * scalar)
        print("Scalar multiplication passed.")

        # Test division (matrix-scalar)
        print(f"Testing scalar division (A / {scalar:.4f})...")
        F = A / scalar
        assert_close(F, np.array(A.matrix) / scalar)
        print("Scalar division passed.")

    print(f"\nAll {num_tests} matrix operations tests passed.")

def test_matrix_properties(num_tests=50):
    print(f"\nTesting matrix properties ({num_tests} tests):")
    for i in range(num_tests):
        size = random.randint(2, 5)
        A = random_matrix(size, size)
        np_A = np.array(A.matrix)

        print(f"\nTest {i+1}:")
        print("Matrix A:")
        print_matrix(A.matrix)

        # Test transpose
        print("Testing transpose...")
        assert_close(A.transpose(), np_A.T)
        print("Transpose passed.")

        # Test determinant
        print("Testing determinant...")
        our_det = A.determinant()
        np_det = np.linalg.det(np_A)
        print(f"Our determinant: {our_det:.4f}")
        print(f"NumPy determinant: {np_det:.4f}")
        assert_close(our_det, np_det)
        print("Determinant passed.")

        # Test inverse (only for invertible matrices)
        if abs(np.linalg.det(np_A)) > 1e-10:
            print("Testing inverse...")
            A_inv = A.inverse()
            np_A_inv = np.linalg.inv(np_A)
            assert_close(A_inv, np_A_inv)
            print("Inverse passed.")
        else:
            print("Matrix is not invertible, skipping inverse test.")

        # Test rank
        print("Testing rank...")
        our_rank = A.rank()
        np_rank = np.linalg.matrix_rank(np_A)
        print(f"Our rank: {our_rank}")
        print(f"NumPy rank: {np_rank}")
        assert our_rank == np_rank
        print("Rank passed.")

        # Test symmetry
        print("Testing symmetry...")
        our_symmetry = A.is_symmetric()
        np_symmetry = np.allclose(np_A, np_A.T)
        print(f"Our symmetry check: {our_symmetry}")
        print(f"NumPy symmetry check: {np_symmetry}")
        assert our_symmetry == np_symmetry
        print("Symmetry check passed.")

    print(f"\nAll {num_tests} matrix properties tests passed.")

def test_eigenvalues_and_vectors(num_tests=50):
    print(f"\nTesting eigenvalues and eigenvectors ({num_tests} tests):")
    for i in range(num_tests):
        size = random.randint(2, 5)
        A = random_matrix(size, size)
        np_A = np.array(A.matrix)

        print(f"\nTest {i+1}:")
        print("Matrix A:")
        print_matrix(A.matrix)

        # Test eigenvalues
        print("Testing eigenvalues...")
        our_eigenvalues = sorted(A.eigenvalues(), key=lambda x: x.evalf())
        np_eigenvalues = sorted(np.linalg.eigvals(np_A))
        print("Our eigenvalues:", [f"{e.evalf():.4f}" for e in our_eigenvalues])
        print("NumPy eigenvalues:", [f"{e:.4f}" for e in np_eigenvalues])
        assert_close(our_eigenvalues, np_eigenvalues)
        print("Eigenvalues passed.")

        # Test eigenvectors
        print("Testing eigenvectors...")
        our_eigenvectors = A.eigenvectors()
        np_eigenvalues, np_eigenvectors = np.linalg.eig(np_A)

        # Compare the span of eigenvectors
        our_span = Matrix(our_eigenvectors).rank()
        np_span = np.linalg.matrix_rank(np_eigenvectors)
        print(f"Our eigenvector span: {our_span}")
        print(f"NumPy eigenvector span: {np_span}")
        assert our_span == np_span
        print("Eigenvectors passed.")

    print(f"\nAll {num_tests} eigenvalues and eigenvectors tests passed.")

def test_matrix_decompositions(num_tests=50):
    print(f"\nTesting matrix decompositions ({num_tests} tests):")
    for i in range(num_tests):
        size = random.randint(2, 5)
        A = random_matrix(size, size)
        np_A = np.array(A.matrix)

        print(f"\nTest {i+1}:")
        print("Matrix A:")
        print_matrix(A.matrix)

        # Test diagonalization (only for diagonalizable matrices)
        print("Testing diagonalization...")
        try:
            P, D = A.diagonalize()
            
            # Verify A = PDP^-1
            result = P * D * P.inverse()
            assert_close(result, np_A)
            print("Diagonalization passed.")
        except ValueError as e:
            print(f"Matrix is not diagonalizable: {e}")

    print(f"\nAll {num_tests} matrix decompositions tests completed.")

def test_matrix_norms(num_tests=50):
    print(f"\nTesting matrix norms ({num_tests} tests):")
    for i in range(num_tests):
        rows, cols = random.randint(2, 5), random.randint(2, 5)
        A = random_matrix(rows, cols)
        np_A = np.array(A.matrix)

        print(f"\nTest {i+1}:")
        print("Matrix A:")
        print_matrix(A.matrix)

        # Test Frobenius norm
        print("Testing Frobenius norm...")
        our_norm = A.norm()
        np_norm = np.linalg.norm(np_A, 'fro')
        print(f"Our Frobenius norm: {our_norm:.4f}")
        print(f"NumPy Frobenius norm: {np_norm:.4f}")
        assert_close(our_norm, np_norm)
        print("Frobenius norm passed.")

        # Test vector norm
        print("Testing vector norm...")
        v = [random.uniform(-10, 10) for _ in range(random.randint(2, 5))]
        our_vector_norm = Matrix.vector_norm(v)
        np_vector_norm = np.linalg.norm(np.array(v))
        print(f"Vector: {v}")
        print(f"Our vector norm: {our_vector_norm:.4f}")
        print(f"NumPy vector norm: {np_vector_norm:.4f}")
        assert_close(our_vector_norm, np_vector_norm)
        print("Vector norm passed.")

    print(f"\nAll {num_tests} matrix norms tests passed.")

def run_all_tests():
    random.seed(42)  # For reproducibility
    np.random.seed(42)

    test_matrix_operations()
    test_matrix_properties()
    test_eigenvalues_and_vectors()
    test_matrix_decompositions()
    test_matrix_norms()
    print("\nAll random tests passed successfully!")

# %%
run_all_tests()
# Out:
# Testing matrix operations (50 tests):
#
# Test 1:
# Matrix A:
#   4.8310  -5.1022
#  -7.2092  -7.9501
# Matrix B:
#   4.8134   0.9073
#   1.8099  -9.3643
# Scalar: -8.1261
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * -8.1261)...
# Scalar multiplication passed.
# Testing scalar division (A / -8.1261)...
# Scalar division passed.
#
# Test 2:
# Matrix A:
#   1.2249   4.3204
#   4.0265  -1.6096
#  -1.0158  -4.4362
# Matrix B:
#   7.3860   5.1761
#  -6.8068  -1.5477
#  -4.4426  -5.6937
# Scalar: 5.2699
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * 5.2699)...
# Scalar multiplication passed.
# Testing scalar division (A / 5.2699)...
# Scalar division passed.
#
# Test 3:
# Matrix A:
#  -2.4015  -2.8204
#  -3.1209  -4.7096
# Matrix B:
#  -9.1310  -0.8115
#  -7.5035   8.4459
# Scalar: -8.4240
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * -8.4240)...
# Scalar multiplication passed.
# Testing scalar division (A / -8.4240)...
# Scalar division passed.
#
# Test 4:
# Matrix A:
#   1.5470   4.0914  -9.0835  -5.4420
#  -4.2122  -8.4042  -5.3442  -7.9800
#  -4.4405   2.7137  -2.7034  -2.5964
#  -5.8099  -4.6604   8.7331   2.9607
# Matrix B:
#   2.1826  -6.5772   4.5825  -6.7320
#  -2.4109   9.7905   2.8000   1.1390
#   3.6923   6.8570   5.5200  -5.4190
#  -9.3580  -3.6909  -4.6452  -5.7803
# Scalar: 8.8582
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * 8.8582)...
# Scalar multiplication passed.
# Testing scalar division (A / 8.8582)...
# Scalar division passed.
#
# Test 5:
# Matrix A:
#   3.1088  -2.0874   8.2910
#  -0.8230  -4.7024  -5.0674
#   1.2274  -4.7452   1.6917
#   7.9565  -2.0120  -5.6136
# Matrix B:
#   9.9508   0.1905  -8.1818
#  -9.0577  -7.8070   2.5489
#   5.8416  -1.5568  -8.7294
#  -2.3676   9.9224   0.5823
# Scalar: 9.4216
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * 9.4216)...
# Scalar multiplication passed.
# Testing scalar division (A / 9.4216)...
# Scalar division passed.
#
# Test 6:
# Matrix A:
#   3.6342   0.7394
#  -4.6635   2.8192
# Matrix B:
#  -7.7690  -1.3047
#  -0.9255   9.0763
# Scalar: 7.5171
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * 7.5171)...
# Scalar multiplication passed.
# Testing scalar division (A / 7.5171)...
# Scalar division passed.
#
# Test 7:
# Matrix A:
#   0.1536  -7.8718   2.5060
#   6.8334   0.1533  -6.0218
#  -2.5217  -6.7690   9.0700
#   8.4487   8.3699   1.9789
# Matrix B:
#  -0.2279  -7.7626  -2.7404
#   9.7064   6.1355  -5.2110
#  -5.1826   1.3471  -8.4249
#   4.6382   6.3205   9.5597
# Scalar: 0.6541
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * 0.6541)...
# Scalar multiplication passed.
# Testing scalar division (A / 0.6541)...
# Scalar division passed.
#
# Test 8:
# Matrix A:
#   3.1950   8.9370  -6.6975
#   0.5535   2.1319   9.2873
#   8.5783   5.1053   3.7974
# Matrix B:
#   4.2590  -2.0202   3.4337
#  -2.5316   7.9923  -0.9703
#  -5.0419  -8.7195  -9.5793
# Scalar: 1.0784
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * 1.0784)...
# Scalar multiplication passed.
# Testing scalar division (A / 1.0784)...
# Scalar division passed.
#
# Test 9:
# Matrix A:
#  -8.5801   2.6221
#  -5.4212   8.1084
#   7.1927  -8.5829
# Matrix B:
#  -5.2399   3.3796
#  -5.7153  -7.3538
#   8.7103   1.4209
# Scalar: -0.5466
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * -0.5466)...
# Scalar multiplication passed.
# Testing scalar division (A / -0.5466)...
# Scalar division passed.
#
# Test 10:
# Matrix A:
#  -6.1918  -8.0614  -1.3790  -1.5284  -0.6595
#   4.5815   3.4673   9.6833  -8.0316  -1.9476
#  -3.2139   7.2335  -5.0269  -6.1958  -1.0277
#  -1.5624  -4.4291  -5.0039   8.4653  -1.1374
#   7.2270   1.0065  -8.9882   9.9856   6.7206
# Matrix B:
#   9.3799   8.5273   6.9739  -6.6738  -0.2872
#  -5.7251  -1.9792  -8.8273  -2.4205   9.7062
#  -4.6959   5.6814  -0.8998  -1.5399   9.1464
#   9.9085   1.1154   4.3682  -6.9041  -4.0658
#   9.3742   1.5836   0.8439   4.9595  -8.8567
# Scalar: 1.6836
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * 1.6836)...
# Scalar multiplication passed.
# Testing scalar division (A / 1.6836)...
# Scalar division passed.
#
# Test 11:
# Matrix A:
#   9.2156  -8.3978
#  -6.2835   1.9007
#   3.5043  -5.2959
# Matrix B:
#  -7.6023   7.8057
#  -5.0757   1.8904
#   2.3876  -1.6155
# Scalar: 1.6734
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * 1.6734)...
# Scalar multiplication passed.
# Testing scalar division (A / 1.6734)...
# Scalar division passed.
#
# Test 12:
# Matrix A:
#  -5.9148   4.3238  -5.2263  -2.0843
#   3.4338  -4.0001  -3.6765   5.0373
#  -8.5491  -0.8343   9.9691   9.9219
#  -8.5348  -5.7369  -4.6960   8.6652
# Matrix B:
#   7.6173   7.5854  -2.6095  -6.8451
#   6.6749   4.0708   2.2336   9.7447
#   3.0795  -9.8435   6.3421  -4.0124
#   3.2678   8.7786  -7.3142  -7.6914
# Scalar: -7.8593
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * -7.8593)...
# Scalar multiplication passed.
# Testing scalar division (A / -7.8593)...
# Scalar division passed.
#
# Test 13:
# Matrix A:
#  -4.3649  -5.7874  -3.1424   3.7499
#   7.0583   0.1082  -4.9776   8.1632
#  -8.9840   2.6857   6.5870  -9.1183
# Matrix B:
#  -3.3289  -7.3836   9.5960  -6.7684
#  -1.1633   4.1133   1.2181  -7.7625
#   8.9010   3.8204  -7.0189  -9.2794
# Scalar: -2.6157
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * -2.6157)...
# Scalar multiplication passed.
# Testing scalar division (A / -2.6157)...
# Scalar division passed.
#
# Test 14:
# Matrix A:
#  -7.4511  -3.8348   7.9796   5.9224   7.2141
#   7.9785  -5.7985  -5.0094  -7.9441   5.6023
#   7.6827  -1.8725   2.4132  -6.9089   8.5976
# Matrix B:
#   7.2921   9.5241   6.2154   7.6283  -9.5043
#   4.7313  -3.3563   8.6163   6.0447   7.2813
#   6.2150  -4.6639   5.7475  -7.8381   7.4433
# Scalar: 7.1719
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * 7.1719)...
# Scalar multiplication passed.
# Testing scalar division (A / 7.1719)...
# Scalar division passed.
#
# Test 15:
# Matrix A:
#   6.3317  -0.7939  -3.8962
#   5.9069  -5.4481  -9.5267
#  -6.1374  -3.4348   7.2871
# Matrix B:
#   9.3378  -4.4175   2.8296
#  -2.0064   9.6230   0.7243
#   8.7847  -7.6932   9.4080
# Scalar: -6.4286
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * -6.4286)...
# Scalar multiplication passed.
# Testing scalar division (A / -6.4286)...
# Scalar division passed.
#
# Test 16:
# Matrix A:
#  -7.8319  -1.3087
#   4.5709  -3.7265
#   2.1242   0.2285
#  -2.2961   1.5318
# Matrix B:
#  -4.9055   4.1757
#  -9.9662   8.5115
#   0.7690   4.3886
#   4.8390   3.4126
# Scalar: -2.7156
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * -2.7156)...
# Scalar multiplication passed.
# Testing scalar division (A / -2.7156)...
# Scalar division passed.
#
# Test 17:
# Matrix A:
#   2.4631   3.2677  -7.5075   8.0009
#   0.1425   3.3379  -3.4763   3.9442
# Matrix B:
#   1.0882  -6.1632   3.2986  -2.4171
#   4.9627  -6.5195   1.3821  -1.8785
# Scalar: 6.6745
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * 6.6745)...
# Scalar multiplication passed.
# Testing scalar division (A / 6.6745)...
# Scalar division passed.
#
# Test 18:
# Matrix A:
#  -5.7963   5.7152   2.1332  -3.5550
#  -1.1643   3.5125   0.2235   5.8747
#   9.1966   4.7192   3.1770  -4.3243
#   3.2771   2.3852  -8.1323   9.0400
# Matrix B:
#  -5.3026  -3.7916   6.1313  -7.0529
#  -9.0757   9.6787   2.2255   5.3698
#  -0.8917   7.7227   1.5134   4.3669
#  -2.3204  -2.0069  -7.0486   3.7524
# Scalar: 7.8532
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * 7.8532)...
# Scalar multiplication passed.
# Testing scalar division (A / 7.8532)...
# Scalar division passed.
#
# Test 19:
# Matrix A:
#  -5.6232   6.0822   3.9182  -0.7090   1.1481
#   8.3494  -7.5728  -7.3332  -0.7071   0.6226
# Matrix B:
#   1.1785  -3.6540   5.1050  -1.1485   6.3001
#   7.8404  -1.4652   8.1371  -1.0817  -6.8168
# Scalar: 7.2299
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * 7.2299)...
# Scalar multiplication passed.
# Testing scalar division (A / 7.2299)...
# Scalar division passed.
#
# Test 20:
# Matrix A:
#   5.0355   6.7973  -4.4538   5.5535
#  -0.3081  -5.2151  -1.2025   4.2709
#  -5.3101  -3.2830   7.8605  -8.3884
#  -6.9834  -2.3393  -6.9439  -5.7209
#  -1.7026  -3.3824  -0.6815  -8.7547
# Matrix B:
#   6.6578  -2.2105   5.3959   8.9212
#  -9.6094   7.6131   1.5138  -0.4604
#   8.8548  -4.0277  -2.2003   7.8328
#   6.7146   0.7644   4.6927   5.9974
#   7.9562  -0.2354  -4.5413  -0.2872
# Scalar: -2.2229
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * -2.2229)...
# Scalar multiplication passed.
# Testing scalar division (A / -2.2229)...
# Scalar division passed.
#
# Test 21:
# Matrix A:
#   6.8101   8.3908   9.6144
#   0.6825   8.1386   1.8379
#   3.2600  -8.3211  -1.4277
#   7.3370  -6.3654  -4.7969
#  -3.4529  -0.9060  -3.2500
# Matrix B:
#   7.5928  -4.4349   9.0241
#  -1.5687   6.6982  -0.5939
#   4.9805  -8.9583   9.0384
#  -5.5156  -8.6276   9.1457
#  -9.1948  -9.3794  -5.0543
# Scalar: 6.7846
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * 6.7846)...
# Scalar multiplication passed.
# Testing scalar division (A / 6.7846)...
# Scalar division passed.
#
# Test 22:
# Matrix A:
#  -7.4756   3.3892   1.2794
#  -5.6407   3.9893   5.3380
#  -6.6442   2.1449   4.9585
# Matrix B:
#  -7.7093   6.3860   9.2944
#  -7.8380  -9.4864  -3.7609
#   3.5469   9.1635  -2.0669
# Scalar: 4.3003
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * 4.3003)...
# Scalar multiplication passed.
# Testing scalar division (A / 4.3003)...
# Scalar division passed.
#
# Test 23:
# Matrix A:
#  -7.9620   5.4496   7.0059
#   2.0082  -7.5789   9.6769
# Matrix B:
#   5.6527  -3.0559  -1.4324
#  -2.5886   0.1192  -3.1754
# Scalar: 6.9915
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * 6.9915)...
# Scalar multiplication passed.
# Testing scalar division (A / 6.9915)...
# Scalar division passed.
#
# Test 24:
# Matrix A:
#  -1.3295  -2.7562
#   7.8315  -0.8052
#  -6.9402  -6.4773
#   0.4349   3.0091
#   2.3182   8.3924
# Matrix B:
#   5.4928  -0.7025
#   6.5147   1.8495
#  -3.5539  -5.0901
#   8.6924  -4.4214
#  -0.9840   5.0095
# Scalar: 1.3970
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * 1.3970)...
# Scalar multiplication passed.
# Testing scalar division (A / 1.3970)...
# Scalar division passed.
#
# Test 25:
# Matrix A:
#  -9.4260   7.0191  -6.3632  -5.7576
#   5.9566  -3.1932   7.6064   4.0237
#  -4.4746  -9.7970   8.9613  -8.2877
#   4.4015  -0.2284   5.1633   3.8122
#   2.9181  -0.1836   5.8587  -8.1389
# Matrix B:
#  -5.5681   3.8357  -3.8759   1.6311
#  -0.5348   0.6184  -1.4899   4.9187
#  -3.3842   4.0571  -4.5817  -4.9719
#  -7.5869  -6.1483  -7.6089   0.7173
#   5.2438  -6.2970  -5.6723  -0.3160
# Scalar: 4.4917
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * 4.4917)...
# Scalar multiplication passed.
# Testing scalar division (A / 4.4917)...
# Scalar division passed.
#
# Test 26:
# Matrix A:
#   6.6526  -4.0751
#  -2.7824  -3.9546
#   4.1604  -7.4683
#  -9.0897  -8.9095
# Matrix B:
#  -4.1573   8.8818
#   2.7574   5.0558
#  -7.9482  -9.7547
#  -4.3132  -0.4257
# Scalar: -3.1859
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * -3.1859)...
# Scalar multiplication passed.
# Testing scalar division (A / -3.1859)...
# Scalar division passed.
#
# Test 27:
# Matrix A:
#   8.8213  -0.4454   6.4423  -1.9859
#  -8.5184   2.5889  -8.9278  -7.0160
# Matrix B:
#   1.2568  -3.9233   9.8784  -7.6310
#   5.2889   2.1264   5.8148  -5.4863
# Scalar: 0.4515
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * 0.4515)...
# Scalar multiplication passed.
# Testing scalar division (A / 0.4515)...
# Scalar division passed.
#
# Test 28:
# Matrix A:
#  -4.0529   1.7705  -1.4234   1.3726  -8.7954
#   9.2022  -8.0153   5.2547   2.5103  -4.7071
#  -8.3763  -5.2027   1.0398  -6.8693  -1.8296
#   3.7874  -0.6018  -9.3472  -4.2379  -4.3456
#   7.1921  -8.5764  -5.3315  -4.7089   5.8250
# Matrix B:
#   1.7958   6.0781  -6.0436  -7.7045  -5.5038
#  -7.0202  -4.6874  -7.1553  -8.8072   5.8526
#   1.9009   6.4848   8.4239  -1.2169  -0.6260
#  -3.9182  -1.9498  -4.5551   0.7996  -1.2448
#   1.9607   7.7885   4.6907   2.0743  -9.4827
# Scalar: -5.4215
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * -5.4215)...
# Scalar multiplication passed.
# Testing scalar division (A / -5.4215)...
# Scalar division passed.
#
# Test 29:
# Matrix A:
#   1.5249   5.2622  -6.4962   0.3793
#  -1.1554  -4.4369   9.9389  -1.2823
# Matrix B:
#   6.2849   9.3811  -0.5998  -1.8330
#  -3.5788  -7.9080  -6.7835  -1.7671
# Scalar: -0.0906
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * -0.0906)...
# Scalar multiplication passed.
# Testing scalar division (A / -0.0906)...
# Scalar division passed.
#
# Test 30:
# Matrix A:
#  -0.9035  -3.7097
#  -3.5345   9.4037
#  -1.9165   0.2919
#   9.7624   3.1532
#   0.8519  -1.7350
# Matrix B:
#  -6.2483  -2.7644
#   5.1289   2.5082
#   5.1998  -5.9288
#   0.9844   8.5535
#  -1.2377   3.9650
# Scalar: -7.5715
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * -7.5715)...
# Scalar multiplication passed.
# Testing scalar division (A / -7.5715)...
# Scalar division passed.
#
# Test 31:
# Matrix A:
#  -3.7850  -9.7265  -1.8402
#  -5.5060   6.8281  -7.7308
#   8.9412   2.9542  -6.9206
# Matrix B:
#   8.6531  -4.1628   4.1082
#  -1.6902  -0.3500  -0.5556
#  -0.8643  -7.1072  -6.1878
# Scalar: 1.9876
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * 1.9876)...
# Scalar multiplication passed.
# Testing scalar division (A / 1.9876)...
# Scalar division passed.
#
# Test 32:
# Matrix A:
#  -4.4751   5.8001
#  -1.7012   8.6850
#   0.1548   6.4110
# Matrix B:
#  -4.3432  -4.0289
#   1.7388   9.9780
#  -0.2072  -7.0281
# Scalar: 0.7716
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * 0.7716)...
# Scalar multiplication passed.
# Testing scalar division (A / 0.7716)...
# Scalar division passed.
#
# Test 33:
# Matrix A:
#   1.0383   0.8686  -0.8931  -3.5645
#  -6.2270   3.9500   1.4360  -5.3288
#   5.5109  -9.1271   4.8941   4.1046
#   6.2282  -2.2784   3.2738   6.4150
# Matrix B:
#   9.6164  -0.0934  -9.2596   0.0458
#   1.8036   7.3940   7.4838  -1.1939
#   0.5190  -0.8614   4.4489  -1.8004
#   3.0956  -6.9128  -0.6102   9.3841
# Scalar: -3.2288
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * -3.2288)...
# Scalar multiplication passed.
# Testing scalar division (A / -3.2288)...
# Scalar division passed.
#
# Test 34:
# Matrix A:
#   7.0353   7.0468
#   7.1868  -2.3998
#  -3.6668   4.3743
#   5.1880   7.4477
#  -9.2820  -8.6316
# Matrix B:
#   2.6232   8.4186
#   9.9485   4.9353
#  -1.3206  -8.0311
#   2.6750   7.4516
#  -1.1264   3.8800
# Scalar: 8.0685
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * 8.0685)...
# Scalar multiplication passed.
# Testing scalar division (A / 8.0685)...
# Scalar division passed.
#
# Test 35:
# Matrix A:
#   5.9229  -4.1326  -2.5032  -7.0886
#   0.6233   1.3186   5.8504  -6.6003
# Matrix B:
#  -8.4206   7.4168   2.3942  -5.1834
#   8.2566  -7.1376  -0.7770  -4.9205
# Scalar: -4.8935
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * -4.8935)...
# Scalar multiplication passed.
# Testing scalar division (A / -4.8935)...
# Scalar division passed.
#
# Test 36:
# Matrix A:
#   8.0242   3.5522  -6.8405  -1.1654  -3.0887
#   1.7514   2.7788  -1.5138  -4.9980   6.9061
# Matrix B:
#  -6.0157  -2.3061  -0.3358  -5.2559   1.4385
#   1.4962   9.8538  -4.0954   9.5589   3.1646
# Scalar: -4.5104
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * -4.5104)...
# Scalar multiplication passed.
# Testing scalar division (A / -4.5104)...
# Scalar division passed.
#
# Test 37:
# Matrix A:
#   6.6568   8.0587   5.5148  -5.3976   6.0386
#  -5.6199  -6.1974  -4.9875   5.1115   5.3494
# Matrix B:
#   3.6171  -7.2644  -8.0567   2.5492  -9.2115
#   5.7722  -9.3327  -2.7028  -7.3718   8.1926
# Scalar: -3.4656
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * -3.4656)...
# Scalar multiplication passed.
# Testing scalar division (A / -3.4656)...
# Scalar division passed.
#
# Test 38:
# Matrix A:
#  -5.9841   5.7303   7.5292
#  -2.6828   0.0359  -4.5495
#  -6.7091   8.2810   8.8838
#   9.3477  -4.0972   7.4079
#   6.0847  -0.6334  -8.4940
# Matrix B:
#   5.0830  -5.4877   3.5265
#   3.4881  -2.0518   6.9149
#   1.1463  -8.1939  -2.1085
#  -4.7108  -7.5282  -2.6283
#   4.9802  -4.7568  -2.3795
# Scalar: 2.7710
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * 2.7710)...
# Scalar multiplication passed.
# Testing scalar division (A / 2.7710)...
# Scalar division passed.
#
# Test 39:
# Matrix A:
#   3.4967  -0.5705
#   2.3909   8.8634
#  -3.4399   2.2016
#   2.9530   2.7081
# Matrix B:
#  -0.7146   4.0215
#   2.9848  -7.6665
#  -9.0931  -9.2558
#   9.9185  -7.6776
# Scalar: -5.3040
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * -5.3040)...
# Scalar multiplication passed.
# Testing scalar division (A / -5.3040)...
# Scalar division passed.
#
# Test 40:
# Matrix A:
#  -0.9271   3.4097   4.8628   8.9195  -1.6175
#   4.8454  -6.9095  -1.7023  -8.0196  -0.2131
#  -1.8377   9.0304  -9.3457  -2.5894  -1.1323
# Matrix B:
#   9.0111   7.1090  -8.0129   3.7136   0.8893
#   9.5569  -2.8265  -2.0372  -6.2038  -7.5568
#   6.9607  -0.9057   3.2554   2.8341   1.9429
# Scalar: -9.5729
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * -9.5729)...
# Scalar multiplication passed.
# Testing scalar division (A / -9.5729)...
# Scalar division passed.
#
# Test 41:
# Matrix A:
#   9.7764   5.7396  -5.8959
#   6.5964   1.0842   1.7277
#   6.2611  -5.3400   5.4874
#   5.7729   1.9196  -4.4545
# Matrix B:
#   9.6806   9.7505   0.8043
#   5.9703  -7.8015   7.3290
#  -7.3639  -2.8352   5.7686
#   1.7771  -9.6844  -4.6926
# Scalar: -7.4648
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * -7.4648)...
# Scalar multiplication passed.
# Testing scalar division (A / -7.4648)...
# Scalar division passed.
#
# Test 42:
# Matrix A:
#   4.9133  -0.4751
#   5.5603   0.2648
#  -7.8189   0.0768
#   8.9083  -9.1327
#   5.6645   7.3396
# Matrix B:
#   0.4290  -0.8391
#   9.2805  -8.7835
#  -0.4204  -1.9677
#   3.7219  -0.1946
#   8.1940  -8.5302
# Scalar: -8.3842
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * -8.3842)...
# Scalar multiplication passed.
# Testing scalar division (A / -8.3842)...
# Scalar division passed.
#
# Test 43:
# Matrix A:
#  -7.4762   2.4863
#   1.7073   4.2431
#  -2.3819   1.9478
# Matrix B:
#  -4.1020   0.1110
#  -1.3960   5.8619
#  -7.7117   3.0943
# Scalar: 7.5541
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * 7.5541)...
# Scalar multiplication passed.
# Testing scalar division (A / 7.5541)...
# Scalar division passed.
#
# Test 44:
# Matrix A:
#  -0.9689  -5.4301  -3.2214  -0.9300  -1.6802
#  -8.0983  -1.4647   3.3022  -2.5140  -6.9472
#   8.4597  -8.6573   6.6354  -8.1354  -8.0687
# Matrix B:
#   4.7759   6.2354   1.1274   1.7293   1.2317
#  -3.4071  -7.5554  -2.9280   3.3068   5.0057
#   7.3618   4.4212   9.3680   2.0082  -2.9671
# Scalar: 1.5584
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * 1.5584)...
# Scalar multiplication passed.
# Testing scalar division (A / 1.5584)...
# Scalar division passed.
#
# Test 45:
# Matrix A:
#   3.1347  -5.5151  -7.8356
#   6.9075  -2.6488   5.2521
#   1.4820   6.1444   6.9031
# Matrix B:
#   9.4909   6.3685   2.2715
#   2.8540  -9.4749   8.5817
#   6.5892  -4.6510  -6.3917
# Scalar: 4.0540
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * 4.0540)...
# Scalar multiplication passed.
# Testing scalar division (A / 4.0540)...
# Scalar division passed.
#
# Test 46:
# Matrix A:
#  -2.9795  -6.3719  -7.1350   3.1469
#  -8.6083   4.8194   9.4362  -8.1648
#   0.6097  -2.4761  -0.9271  -6.8518
#  -3.7673  -3.5123   8.8281   1.9245
# Matrix B:
#   7.6668  -6.8884   5.0887  -9.0048
#  -8.3684  -1.1377  -1.5197   2.1415
#  -1.7163  -5.6886   0.2469  -3.0965
#  -7.7822   3.5644   1.8627   0.5387
# Scalar: -3.8316
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * -3.8316)...
# Scalar multiplication passed.
# Testing scalar division (A / -3.8316)...
# Scalar division passed.
#
# Test 47:
# Matrix A:
#   9.6889  -8.9044  -5.9115   8.9065   5.3470
#   5.2832  -4.2111  -7.6003  -0.0523  -1.3869
#  -7.4163   0.6516  -5.3978   1.1745   3.3610
# Matrix B:
#  -2.9167  -2.0586   4.8408  -1.2756  -0.8049
#  -8.4427  -3.7388  -1.4143  -1.9115   2.8028
#  -4.2097  -1.8994   9.3240  -6.5625   8.9523
# Scalar: -0.7981
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * -0.7981)...
# Scalar multiplication passed.
# Testing scalar division (A / -0.7981)...
# Scalar division passed.
#
# Test 48:
# Matrix A:
#  -1.2658  -7.8827
#  -1.2865  -1.9910
#  -8.4271   7.4105
#   4.9161  -5.5686
# Matrix B:
#   5.5824  -8.4724
#   2.6645   0.6121
#  -6.1219   5.5246
#  -2.9780   9.1645
# Scalar: 2.9089
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * 2.9089)...
# Scalar multiplication passed.
# Testing scalar division (A / 2.9089)...
# Scalar division passed.
#
# Test 49:
# Matrix A:
#  -7.9439  -4.8806  -6.5300
#  -6.9426   5.1830  -8.4929
#   9.0258   2.5590  -0.7209
# Matrix B:
#   1.2747   1.5894   3.6227
#   7.6410   2.8598   9.7306
#  -3.5358   9.4195  -3.6772
# Scalar: -1.2047
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * -1.2047)...
# Scalar multiplication passed.
# Testing scalar division (A / -1.2047)...
# Scalar division passed.
#
# Test 50:
# Matrix A:
#   2.6277   5.9266   1.8284  -2.9612  -8.5162
#  -0.7652  -9.2479  -2.6252  -4.2585   2.8933
#   9.5474  -8.1941   1.8816  -2.3104   1.6066
#   9.0846   4.7784  -9.1795   8.1810   1.4331
#  -6.2352   2.1001   0.0273   9.1544  -0.9895
# Matrix B:
#   6.2193   6.7475   9.6477  -8.3134   2.9225
#  -9.2172   4.1524   9.8197   0.4814   2.1961
#  -2.7220   8.3587  -2.2517   5.4893   3.5780
#  -8.9527   2.6177  -3.3070  -3.4062   1.1593
#  -2.2687  -4.9601   7.0313   9.2882   2.0540
# Scalar: -6.9925
# Testing addition (A + B)...
# Addition passed.
# Testing subtraction (A - B)...
# Subtraction passed.
# Testing scalar multiplication (A * -6.9925)...
# Scalar multiplication passed.
# Testing scalar division (A / -6.9925)...
# Scalar division passed.
#
# All 50 matrix operations tests passed.
#
# Testing matrix properties (50 tests):
#
# Test 1:
# Matrix A:
#   1.6548  -7.1714
#  -3.0036   9.3539
# Testing transpose...
# Transpose passed.
# Testing determinant...
# Our determinant: -6.0612
# NumPy determinant: -6.0612
# Determinant passed.
# Testing inverse...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 run_all_tests()
#
# Cell In[13], line 217, in run_all_tests()
#     214 np.random.seed(42)
#     216 test_matrix_operations()
# --> 217 test_matrix_properties()
#     218 test_eigenvalues_and_vectors()
#     219 test_matrix_decompositions()
#
# Cell In[13], line 92, in test_matrix_properties(num_tests)
#      90 if abs(np.linalg.det(np_A)) > 1e-10:
#      91     print("Testing inverse...")
# ---> 92     A_inv = A.inverse()
#      93     np_A_inv = np.linalg.inv(np_A)
#      94     assert_close(A_inv, np_A_inv)
#
# File e:\Workspace\linear-algebra\matrix.py:102, in Matrix.inverse(self)
#     100 def inverse(self):
#     101     if not self.invertible():
# --> 102         raise ValueError("Matrix is not invertible")
#     103     det = self.determinant()
#     104     return self.adjoint() / det
#
# ValueError: Matrix is not invertible
